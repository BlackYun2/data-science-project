# %% [markdown]
# # Introduction to Data Science
#
#
# ## Lab 6: Exercise
#
# **British University in Egypt**<br>
# **Instructors:** Nahla Barakt <br>

# %%
from IPython.display import HTML
style = "<style>div.exercise { background-color: #ffcccc;border-color: #E9967A; border-left: 5px solid #800080; padding: 0.5em;}</style>"
HTML(style)
# Out:
# <style>div.exercise { background-color: #ffcccc;border-color: #E9967A; border-left: 5px solid #800080; padding: 0.5em;}</style>

# %%
import pandas as pd

# %% [markdown]
# #### Add % in front and end of every single word in a given string str:
# "Fall is Awesome in Alabama" <br> only using **list comprehensions**.
#
# #### Output:
# ['%Fall%','%is%','%Awesome%','%in%','%Alabama%']

# %%
str = "Fall is Awesome in Alabama"
####################YourCode####################
['%'+word+'%' for word in str.split()]
# Out:
# ['%Fall%', '%is%', '%Awesome%', '%in%', '%Alabama%']

# %% [markdown]
# #### Write a code that creates the next three lists <br>
# ['S001', 'S002', 'S003', 'S004']<br>
# ['Adina Park', 'Leyton Marsh', 'Duncan Boyle', 'Saim Richards']<br>
# [85, 98, 89, 92]<br>
#
#
# #### Then Convert the lists to Nested dictionary :
# {'S001': {'Adina Park': 85}, 'S002': {'Leyton Marsh': 98}, 'S003': {'Duncan Boyle': 89}, 'S004': {'Saim Richards': 92}}

# %%
l1=['S001','S002','S003','S004']
l2=['Adina Park','Leyton Marsh','Duncan Boyle','Saim Richards']
l3=[85, 98, 89, 92]

####################YourCode####################
d=dict()
for i in range(len(l1)):
    d[l1[i]]={l2[i]:l3[i]}
    
d
# Out:
# {'S001': {'Adina Park': 85},
#  'S002': {'Leyton Marsh': 98},
#  'S003': {'Duncan Boyle': 89},
#  'S004': {'Saim Richards': 92}}

# %%
# Download the dataset on e-learning that is called Exercise dataset and read it as dataframe
# Print the tail of the dataframe
####################YourCode####################
df=pd.read_csv('cscpopendata.csv')
df.tail()
# Out:
#         CDPHId                                        ProductName    CSFId  \
# 114630   41523               HYDRA-LIP TRANSLUCENT COLOR LIPSTICK  65001.0
# 114631   41523               HYDRA-LIP TRANSLUCENT COLOR LIPSTICK  65002.0
# 114632   41523               HYDRA-LIP TRANSLUCENT COLOR LIPSTICK  65003.0
# 114633   41523               HYDRA-LIP TRANSLUCENT COLOR LIPSTICK  65004.0
# 114634   41524  OLD SPICE GENTLEMENS BLEND ALOE AND WILD SAGE ...      NaN
#
#                  CSF  CompanyId                   CompanyName  BrandName  \
# 114630     Rosa Soft       1259               Yanbal USA, Inc     YANBAL
# 114631  Malva Spirit       1259               Yanbal USA, Inc     YANBAL
# 114632  Rojo Fashion       1259               Yanbal USA, Inc     YANBAL
# 114633  Terra Mystic       1259               Yanbal USA, Inc     YANBAL
# 114634           NaN         86  The Procter & Gamble Company  Old Spice
#
#         PrimaryCategoryId                  PrimaryCategory  SubCategoryId  \
# 114630                 44  Makeup Products (non-permanent)             53
# 114631                 44  Makeup Products (non-permanent)             53
# 114632                 44  Makeup Products (non-permanent)             53
# 114633                 44  Makeup Products (non-permanent)             53
# 114634                  6                    Bath Products            159
#
#         ...   CasNumber  ChemicalId      ChemicalName  InitialDateReported  \
# 114630  ...  13463-67-7       68059  Titanium dioxide           06/19/2020
# 114631  ...  13463-67-7       68060  Titanium dioxide           06/19/2020
# 114632  ...  13463-67-7       68061  Titanium dioxide           06/19/2020
# 114633  ...  13463-67-7       68062  Titanium dioxide           06/19/2020
# 114634  ...  13463-67-7       68074  Titanium dioxide           06/23/2020
#
#        MostRecentDateReported DiscontinuedDate ChemicalCreatedAt  \
# 114630             06/19/2020              NaN        06/19/2020
# 114631             06/19/2020              NaN        06/19/2020
# 114632             06/19/2020              NaN        06/19/2020
# 114633             06/19/2020              NaN        06/19/2020
# 114634             06/23/2020              NaN        06/23/2020
#
#        ChemicalUpdatedAt ChemicalDateRemoved ChemicalCount
# 114630        06/19/2020                 NaN             1
# 114631        06/19/2020                 NaN             1
# 114632        06/19/2020                 NaN             1
# 114633        06/19/2020                 NaN             1
# 114634        06/23/2020                 NaN             1
#
# [5 rows x 22 columns]

# %%
## Explore the dataset

####################YourCode####################
df.shape
# Out:
# (114635, 22)

# %%
df.columns
# Out:
# Index(['CDPHId', 'ProductName', 'CSFId', 'CSF', 'CompanyId', 'CompanyName',
#        'BrandName', 'PrimaryCategoryId', 'PrimaryCategory', 'SubCategoryId',
#        'SubCategory', 'CasId', 'CasNumber', 'ChemicalId', 'ChemicalName',
#        'InitialDateReported', 'MostRecentDateReported', 'DiscontinuedDate',
#        'ChemicalCreatedAt', 'ChemicalUpdatedAt', 'ChemicalDateRemoved',
#        'ChemicalCount'],
#       dtype='object')

# %%
df.describe()
# Out:
#               CDPHId         CSFId      CompanyId  PrimaryCategoryId  \
# count  114635.000000  80662.000000  114635.000000      114635.000000
# mean    20304.858987  32608.658377     450.641532          51.076294
# std     12489.052554  19089.443910     409.533093          20.474341
# min         2.000000      1.000000       4.000000           1.000000
# 25%      8717.000000  15789.000000      86.000000          44.000000
# 50%     20895.000000  32541.000000     297.000000          44.000000
# 75%     31338.500000  48717.750000     798.000000          59.000000
# max     41524.000000  65009.000000    1391.000000         111.000000
#
#        SubCategoryId          CasId     ChemicalId  ChemicalCount
# count  114635.000000  114635.000000  114635.000000  114635.000000
# mean       66.819252     674.094107   32837.556959       1.288359
# std        35.822097     149.214101   20439.412299       0.636418
# min         3.000000       2.000000       0.000000       0.000000
# 25%        48.000000     656.000000   13990.000000       1.000000
# 50%        52.000000     656.000000   32055.000000       1.000000
# 75%        65.000000     656.000000   51578.500000       1.000000
# max       172.000000    1242.000000   68074.000000       9.000000

# %%
df.dtypes
# Out:
# CDPHId                      int64
# ProductName                object
# CSFId                     float64
# CSF                        object
# CompanyId                   int64
# CompanyName                object
# BrandName                  object
# PrimaryCategoryId           int64
# PrimaryCategory            object
# SubCategoryId               int64
# SubCategory                object
# CasId                       int64
# CasNumber                  object
# ChemicalId                  int64
# ChemicalName               object
# InitialDateReported        object
# MostRecentDateReported     object
# DiscontinuedDate           object
# ChemicalCreatedAt          object
# ChemicalUpdatedAt          object
# ChemicalDateRemoved        object
# ChemicalCount               int64
# dtype: object

# %%
## Check number of nulls in the dataframe

####################YourCode####################
df.isna().sum()
# Out:
# CDPHId                         0
# ProductName                    0
# CSFId                      33973
# CSF                        34397
# CompanyId                      0
# CompanyName                    0
# BrandName                    216
# PrimaryCategoryId              0
# PrimaryCategory                0
# SubCategoryId                  0
# SubCategory                    0
# CasId                          0
# CasNumber                   6476
# ChemicalId                     0
# ChemicalName                   0
# InitialDateReported            0
# MostRecentDateReported         0
# DiscontinuedDate          101715
# ChemicalCreatedAt              0
# ChemicalUpdatedAt              0
# ChemicalDateRemoved       111650
# ChemicalCount                  0
# dtype: int64

# %%
## Drop DiscontinuedDate,ChemicalDateRemoved, CasNumber, CSF columns

####################YourCode####################
df.drop(['CasNumber','CSF','DiscontinuedDate','ChemicalDateRemoved'],axis=1,inplace=True)

# %%
## Imputate CasNumber nulls by mean
####################YourCode####################
df['CSFId'].fillna((df['CSFId'].mean()), inplace=True)

# %%
## Replace BrandName nulls by unKnown

####################YourCode####################
df['BrandName'][df['BrandName'].isna()]='unKnown'
# Out:
# <ipython-input-13-cdbe8bc649be>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BrandName'][df['BrandName'].isna()]='unKnown'

# %%
## Reterive columns CDPHId, PrimaryCategoryId, and ChemicalCount Columns

####################YourCode####################
df[['CDPHId','PrimaryCategoryId','ChemicalCount']]
# Out:
#         CDPHId  PrimaryCategoryId  ChemicalCount
# 0            2                 44              1
# 1            3                 18              2
# 2            3                 18              2
# 3            4                 44              1
# 4            5                 44              1
# ...        ...                ...            ...
# 114630   41523                 44              1
# 114631   41523                 44              1
# 114632   41523                 44              1
# 114633   41523                 44              1
# 114634   41524                  6              1
#
# [114635 rows x 3 columns]

# %%
## Check number of nulls again

####################YourCode####################
df.isna().sum()
# Out:
# CDPHId                    0
# ProductName               0
# CSFId                     0
# CompanyId                 0
# CompanyName               0
# BrandName                 0
# PrimaryCategoryId         0
# PrimaryCategory           0
# SubCategoryId             0
# SubCategory               0
# CasId                     0
# ChemicalId                0
# ChemicalName              0
# InitialDateReported       0
# MostRecentDateReported    0
# ChemicalCreatedAt         0
# ChemicalUpdatedAt         0
# ChemicalCount             0
# dtype: int64

# %%
## Reterive last 500 rows

####################YourCode####################
df.iloc[-500:, ]
# Out:
#         CDPHId                                        ProductName  \
# 114135   41396  DIORSHOW 24H STYLO 24H Wear Eyeliner Intense C...
# 114136   41397  DIORSHOW ICONIC OVERCURL Spectacular 24h Volum...
# 114137   41398  ROUGE DIOR Couture colour lipstick floral lip ...
# 114138   41398  ROUGE DIOR Couture colour lipstick floral lip ...
# 114139   41398  ROUGE DIOR Couture colour lipstick floral lip ...
# ...        ...                                                ...
# 114630   41523               HYDRA-LIP TRANSLUCENT COLOR LIPSTICK
# 114631   41523               HYDRA-LIP TRANSLUCENT COLOR LIPSTICK
# 114632   41523               HYDRA-LIP TRANSLUCENT COLOR LIPSTICK
# 114633   41523               HYDRA-LIP TRANSLUCENT COLOR LIPSTICK
# 114634   41524  OLD SPICE GENTLEMENS BLEND ALOE AND WILD SAGE ...
#
#                CSFId  CompanyId                   CompanyName  \
# 114135  64809.000000        328        Parfums Christian Dior
# 114136  64810.000000        328        Parfums Christian Dior
# 114137  64811.000000        328        Parfums Christian Dior
# 114138  64812.000000        328        Parfums Christian Dior
# 114139  64813.000000        328        Parfums Christian Dior
# ...              ...        ...                           ...
# 114630  65001.000000       1259               Yanbal USA, Inc
# 114631  65002.000000       1259               Yanbal USA, Inc
# 114632  65003.000000       1259               Yanbal USA, Inc
# 114633  65004.000000       1259               Yanbal USA, Inc
# 114634  32608.658377         86  The Procter & Gamble Company
#
#                      BrandName  PrimaryCategoryId  \
# 114135  Parfums Christian Dior                 44
# 114136  Parfums Christian Dior                 44
# 114137  Parfums Christian Dior                 44
# 114138  Parfums Christian Dior                 44
# 114139  Parfums Christian Dior                 44
# ...                        ...                ...
# 114630                  YANBAL                 44
# 114631                  YANBAL                 44
# 114632                  YANBAL                 44
# 114633                  YANBAL                 44
# 114634               Old Spice                  6
#
#                         PrimaryCategory  SubCategoryId  \
# 114135  Makeup Products (non-permanent)             46
# 114136  Makeup Products (non-permanent)            162
# 114137  Makeup Products (non-permanent)             53
# 114138  Makeup Products (non-permanent)             53
# 114139  Makeup Products (non-permanent)             53
# ...                                 ...            ...
# 114630  Makeup Products (non-permanent)             53
# 114631  Makeup Products (non-permanent)             53
# 114632  Makeup Products (non-permanent)             53
# 114633  Makeup Products (non-permanent)             53
# 114634                    Bath Products            159
#
#                                        SubCategory  CasId  ChemicalId  \
# 114135                    Eyeliner/Eyebrow Pencils   1104       67798
# 114136                    Mascara/Eyelash Products    656       67799
# 114137  Lip Color - Lipsticks, Liners, and Pencils    656       67800
# 114138  Lip Color - Lipsticks, Liners, and Pencils    656       67800
# 114139  Lip Color - Lipsticks, Liners, and Pencils    656       67800
# ...                                            ...    ...         ...
# 114630  Lip Color - Lipsticks, Liners, and Pencils    656       68059
# 114631  Lip Color - Lipsticks, Liners, and Pencils    656       68060
# 114632  Lip Color - Lipsticks, Liners, and Pencils    656       68061
# 114633  Lip Color - Lipsticks, Liners, and Pencils    656       68062
# 114634                       Body Washes and Soaps    656       68074
#
#             ChemicalName InitialDateReported MostRecentDateReported  \
# 114135      Carbon black          04/17/2020             04/17/2020
# 114136  Titanium dioxide          04/17/2020             04/17/2020
# 114137  Titanium dioxide          04/17/2020             04/17/2020
# 114138  Titanium dioxide          04/17/2020             04/17/2020
# 114139  Titanium dioxide          04/17/2020             04/17/2020
# ...                  ...                 ...                    ...
# 114630  Titanium dioxide          06/19/2020             06/19/2020
# 114631  Titanium dioxide          06/19/2020             06/19/2020
# 114632  Titanium dioxide          06/19/2020             06/19/2020
# 114633  Titanium dioxide          06/19/2020             06/19/2020
# 114634  Titanium dioxide          06/23/2020             06/23/2020
#
#        ChemicalCreatedAt ChemicalUpdatedAt  ChemicalCount
# 114135        04/17/2020        04/17/2020              2
# 114136        04/17/2020        04/17/2020              1
# 114137        04/17/2020        04/17/2020              1
# 114138        04/17/2020        04/17/2020              1
# 114139        04/17/2020        04/17/2020              1
# ...                  ...               ...            ...
# 114630        06/19/2020        06/19/2020              1
# 114631        06/19/2020        06/19/2020              1
# 114632        06/19/2020        06/19/2020              1
# 114633        06/19/2020        06/19/2020              1
# 114634        06/23/2020        06/23/2020              1
#
# [500 rows x 18 columns]

# %%
## Reterive rows that company id between 1100 and 1260 and company name Contains USA

####################YourCode####################
df[(df['CompanyId'] .between(1100,1260)) & (df['CompanyName'].str.contains('USA')) ]
# Out:
#         CDPHId                              ProductName         CSFId  \
# 79457    28811                  THE BEST SHAMPOO AMAZON  32608.658377
# 80152    29062      Animal Panda Luminous Cover Cushion  32608.658377
# 80153    29062      Animal Panda Luminous Cover Cushion  32608.658377
# 80155    29064  Animal Tiger Long Lasting Cover Cushion  32608.658377
# 84052    30485                              MASCARA DUO  46844.000000
# ...        ...                                      ...           ...
# 114629   41522           EYESHADOW  / ATARDECER NARANJA  65000.000000
# 114630   41523     HYDRA-LIP TRANSLUCENT COLOR LIPSTICK  65001.000000
# 114631   41523     HYDRA-LIP TRANSLUCENT COLOR LIPSTICK  65002.000000
# 114632   41523     HYDRA-LIP TRANSLUCENT COLOR LIPSTICK  65003.000000
# 114633   41523     HYDRA-LIP TRANSLUCENT COLOR LIPSTICK  65004.000000
#
#         CompanyId                   CompanyName            BrandName  \
# 79457        1102                FELPS USA, INC  FELPS PROFESSIONAL
# 80152        1107  SD Biotechnologies USA, Inc.                  SNP
# 80153        1107  SD Biotechnologies USA, Inc.                  SNP
# 80155        1107  SD Biotechnologies USA, Inc.                  SNP
# 84052        1157                SERYSI USA INC          SHELO NABEL
# ...           ...                           ...                  ...
# 114629       1259               Yanbal USA, Inc               YANBAL
# 114630       1259               Yanbal USA, Inc               YANBAL
# 114631       1259               Yanbal USA, Inc               YANBAL
# 114632       1259               Yanbal USA, Inc               YANBAL
# 114633       1259               Yanbal USA, Inc               YANBAL
#
#         PrimaryCategoryId                    PrimaryCategory  SubCategoryId  \
# 79457                  18  Hair Care Products (non-coloring)             27
# 80152                 106               Sun-Related Products            107
# 80153                 106               Sun-Related Products            107
# 80155                 106               Sun-Related Products            107
# 84052                  44    Makeup Products (non-permanent)            162
# ...                   ...                                ...            ...
# 114629                 44    Makeup Products (non-permanent)             48
# 114630                 44    Makeup Products (non-permanent)             53
# 114631                 44    Makeup Products (non-permanent)             53
# 114632                 44    Makeup Products (non-permanent)             53
# 114633                 44    Makeup Products (non-permanent)             53
#
#                                        SubCategory  CasId  ChemicalId  \
# 79457                           Hair Straighteners    969       46565
# 80152         Sunscreen (making a cosmetic claim)     656       47133
# 80153         Sunscreen (making a cosmetic claim)    1108       47134
# 80155         Sunscreen (making a cosmetic claim)     656       47135
# 84052                     Mascara/Eyelash Products    656       49357
# ...                                            ...    ...         ...
# 114629                                  Eye Shadow    656       68058
# 114630  Lip Color - Lipsticks, Liners, and Pencils    656       68059
# 114631  Lip Color - Lipsticks, Liners, and Pencils    656       68060
# 114632  Lip Color - Lipsticks, Liners, and Pencils    656       68061
# 114633  Lip Color - Lipsticks, Liners, and Pencils    656       68062
#
#                          ChemicalName InitialDateReported  \
# 79457                    Cocamide DEA          08/17/2016
# 80152                Titanium dioxide          10/03/2016
# 80153   Aloe vera, whole leaf extract          10/03/2016
# 80155                Titanium dioxide          10/03/2016
# 84052                Titanium dioxide          05/08/2017
# ...                               ...                 ...
# 114629               Titanium dioxide          06/19/2020
# 114630               Titanium dioxide          06/19/2020
# 114631               Titanium dioxide          06/19/2020
# 114632               Titanium dioxide          06/19/2020
# 114633               Titanium dioxide          06/19/2020
#
#        MostRecentDateReported ChemicalCreatedAt ChemicalUpdatedAt  \
# 79457              08/17/2016        08/17/2016        08/17/2016
# 80152              10/03/2016        10/03/2016        10/03/2016
# 80153              10/03/2016        10/03/2016        10/03/2016
# 80155              09/19/2019        10/03/2016        10/03/2016
# 84052              05/18/2017        05/08/2017        05/08/2017
# ...                       ...               ...               ...
# 114629             06/19/2020        06/19/2020        06/19/2020
# 114630             06/19/2020        06/19/2020        06/19/2020
# 114631             06/19/2020        06/19/2020        06/19/2020
# 114632             06/19/2020        06/19/2020        06/19/2020
# 114633             06/19/2020        06/19/2020        06/19/2020
#
#         ChemicalCount
# 79457               1
# 80152               2
# 80153               2
# 80155               1
# 84052               2
# ...               ...
# 114629              1
# 114630              1
# 114631              1
# 114632              1
# 114633              1
#
# [195 rows x 18 columns]

# %%
## Convert MostRecentDateReported, ChemicalCreatedAt, ChemicalUpdatedAt to date type

####################YourCode####################
df['MostRecentDateReported']=pd.to_datetime(df['MostRecentDateReported'])
df['ChemicalCreatedAt']=pd.to_datetime(df['ChemicalCreatedAt'])
df['ChemicalUpdatedAt']=pd.to_datetime(df['ChemicalUpdatedAt'])

# %%
# Group rows of dataframe that brandName is unknown by Chemical Name ant get the sum

####################YourCode####################
df[df['BrandName']=='unKnown'].groupby('ChemicalName').sum()
# Out:
#                                                      CDPHId         CSFId  \
# ChemicalName
# Cocamide DEA                                         196285  3.035380e+05
# Cocamide diethanolamine                             1123343  2.111361e+06
# Mica                                                  20091  3.260866e+04
# Retinol/retinyl esters, when in daily dosages i...    26223  6.521732e+04
# Talc                                                  20091  3.260866e+04
# Titanium dioxide                                     374134  9.520230e+05
# Triethanolamine                                      125029  1.796873e+05
#
#                                                     CompanyId  \
# ChemicalName
# Cocamide DEA                                             7887
# Cocamide diethanolamine                                 51481
# Mica                                                      364
# Retinol/retinyl esters, when in daily dosages i...       1180
# Talc                                                      364
# Titanium dioxide                                        18362
# Triethanolamine                                          4393
#
#                                                     PrimaryCategoryId  \
# ChemicalName
# Cocamide DEA                                                      990
# Cocamide diethanolamine                                          4454
# Mica                                                               44
# Retinol/retinyl esters, when in daily dosages i...                108
# Talc                                                               44
# Titanium dioxide                                                 5220
# Triethanolamine                                                   540
#
#                                                     SubCategoryId  CasId  \
# ChemicalName
# Cocamide DEA                                                 1068  10659
# Cocamide diethanolamine                                      6146  12636
# Mica                                                           48   1001
# Retinol/retinyl esters, when in daily dosages i...            127   1546
# Talc                                                           48    894
# Titanium dioxide                                             6412  76752
# Triethanolamine                                               615   6276
#
#                                                     ChemicalId  ChemicalCount
# ChemicalName
# Cocamide DEA                                            303710             11
# Cocamide diethanolamine                                1733270             78
# Mica                                                     30498              2
# Retinol/retinyl esters, when in daily dosages i...       41006              2
# Talc                                                     30497              2
# Titanium dioxide                                        538573            117
# Triethanolamine                                         193451              6

# %%
df.head(10)
# Out:
#    CDPHId                                        ProductName         CSFId  \
# 0       2   ULTRA COLOR RICH EXTRA PLUMP LIPSTICK-ALL SHADES  32608.658377
# 1       3                         Glover's Medicated Shampoo  32608.658377
# 2       3                         Glover's Medicated Shampoo  32608.658377
# 3       4           PRECISION GLIMMER EYE LINER-ALL SHADES �  32608.658377
# 4       5        AVON BRILLIANT SHINE LIP GLOSS-ALL SHADES �  32608.658377
# 5       6  JILLIAN DEMPSEY FOR AVON CELESTIAL EYESHADOW-A...  32608.658377
# 6       7  ABSOLUTE Precision Color Powder System - All S...    310.000000
# 7       7  ABSOLUTE Precision Color Powder System - All S...    311.000000
# 8       7  ABSOLUTE Precision Color Powder System - All S...    312.000000
# 9       8  ABSOLUTE Precision Color Powder System Opaque ...    313.000000
#
#    CompanyId          CompanyName BrandName  PrimaryCategoryId  \
# 0          4         New Avon LLC      AVON                 44
# 1        338  J. Strickland & Co.  Glover's                 18
# 2        338  J. Strickland & Co.  Glover's                 18
# 3          4         New Avon LLC      AVON                 44
# 4          4         New Avon LLC      AVON                 44
# 5          4         New Avon LLC      AVON                 44
# 6         11    OPI PRODUCTS INC.       OPI                 59
# 7         11    OPI PRODUCTS INC.       OPI                 59
# 8         11    OPI PRODUCTS INC.       OPI                 59
# 9         11    OPI PRODUCTS INC.  ABSOLUTE                 59
#
#                      PrimaryCategory  SubCategoryId  \
# 0    Makeup Products (non-permanent)             53
# 1  Hair Care Products (non-coloring)             25
# 2  Hair Care Products (non-coloring)             25
# 3    Makeup Products (non-permanent)             46
# 4    Makeup Products (non-permanent)             52
# 5    Makeup Products (non-permanent)             48
# 6                      Nail Products             60
# 7                      Nail Products             60
# 8                      Nail Products             60
# 9                      Nail Products             60
#
#                                   SubCategory  CasId  ChemicalId  \
# 0  Lip Color - Lipsticks, Liners, and Pencils    656           6
# 1    Hair Shampoos (making a cosmetic claim)     889           4
# 2    Hair Shampoos (making a cosmetic claim)     293           5
# 3                    Eyeliner/Eyebrow Pencils    656           7
# 4                             Lip Gloss/Shine    656           8
# 5                                  Eye Shadow    656           9
# 6       Artificial Nails and Related Products    656       12178
# 7       Artificial Nails and Related Products    656       12178
# 8       Artificial Nails and Related Products    656       12178
# 9       Artificial Nails and Related Products    656       17903
#
#              ChemicalName InitialDateReported MostRecentDateReported  \
# 0        Titanium dioxide          06/17/2009             2013-08-28
# 1  Distillates (coal tar)          07/01/2009             2009-07-01
# 2               Estragole          07/01/2009             2009-07-01
# 3        Titanium dioxide          07/09/2009             2013-08-28
# 4        Titanium dioxide          07/09/2009             2013-08-28
# 5        Titanium dioxide          07/09/2009             2013-08-28
# 6        Titanium dioxide          07/13/2009             2010-12-30
# 7        Titanium dioxide          07/13/2009             2010-12-30
# 8        Titanium dioxide          07/13/2009             2010-12-30
# 9        Titanium dioxide          07/13/2009             2010-12-30
#
#   ChemicalCreatedAt ChemicalUpdatedAt  ChemicalCount
# 0        2009-07-09        2009-07-09              1
# 1        2009-07-01        2009-07-01              2
# 2        2009-07-02        2009-07-02              2
# 3        2009-07-09        2009-07-09              1
# 4        2009-07-09        2009-07-09              1
# 5        2009-07-09        2009-07-09              1
# 6        2009-12-04        2009-12-04              1
# 7        2009-12-04        2009-12-04              1
# 8        2009-12-04        2009-12-04              1
# 9        2010-06-09        2010-06-09              1

# %%
## Write a regex that gets company name that contains an alphabet small or Captial and special charcter .
## Print the value counts of your mathcing

####################YourCode####################
regex='[A-Za-z]\..*'
df['CompanyName'].str.findall(regex).value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# []                                   82212
# [c.]                                 24279
# [C.]                                  2766
# [S.A.]                                1813
# [o., Ltd.]                             706
# [d.]                                   500
# [L.P.]                                 409
# [C.F.E.B. SISLEY]                      348
# [o.]                                   309
# [S.A - NATURAL PRODUCTS]               271
# [S.A]                                  231
# [O.,LTD.]                              167
# [a.deeming Beauty, Inc.]                84
# [c., a Johnson & Johnson Company]       72
# [J. Strickland & Co.]                   41
# [C. S.r.l.]                             39
# [s.brands, LLC]                         34
# [r. Hauschka Skin Care, Inc.]           30
# [S.R.L.]                                28
# [p.]                                    27
# [P.]                                    26
# [S.C. Johnson & Son, Inc.]              23
# [N.G. Payot]                            22
# [M.T. MOCARA GmbH]                      19
# [n.com LLC]                             18
# [M.F.O.) Ltd.]                          18
# [N.G PAYOT]                             15
# [I.C.O.N. Line, Inc.]                   10
# [O.,LTD]                                10
# [G.O Holdings, Inc.]                     9
# [U.S.A., Inc.]                           8
# [o., Limited]                            8
# [o., Inc.]                               7
# [O., LTD.]                               7
# [o.,Ltd.]                                7
# [S.p.A.]                                 7
# [r. Nona International LTD]              6
# [t. Ciccarelli SpA]                      6
# [o., Ltd]                                5
# [y. Ltd.]                                5
# [O., LTD]                                4
# [E. Excel, LLC]                          4
# [l.m USA INC]                            4
# [r. Babor GmbH & Co. KG]                 3
# [W. W. Grainger, Inc.,]                  3
# [O., INC.]                               2
# [O., Limited]                            2
# [S.L.]                                   2
# [D.]                                     2
# [E.T. Browne Drug Co. Inc.]              2
# [o.,Ltd]                                 2
# [A. P. Deauville, LLC]                   1
# [U.S., Inc.]                             1
# [L.L.C.]                                 1
# Name: CompanyName, dtype: int64

# %%
# Use the results of previous regex and get the rows that matching the regex

####################YourCode####################
df[df['CompanyName'].str.findall(regex).str.len()>0]
# Out:
#         CDPHId                                        ProductName  \
# 1            3                         Glover's Medicated Shampoo
# 2            3                         Glover's Medicated Shampoo
# 6            7  ABSOLUTE Precision Color Powder System - All S...
# 7            7  ABSOLUTE Precision Color Powder System - All S...
# 8            7  ABSOLUTE Precision Color Powder System - All S...
# ...        ...                                                ...
# 114568   41502   EYE-CONIC MULTI-FINISH EYE PALETTE EXTRA-VAGANCE
# 114569   41503     BROW WOW DUO BROW POWDER PENCIL AND TINTED GEL
# 114570   41504                     STAR SHAPE SHOWER GEL 1.5FL OZ
# 114571   41505                         HAND CREAM SWEET PEA 1.5OZ
# 114572   41506              HAND CREAM VANILLA BROWN SUGAR 1.5 OZ
#
#                CSFId  CompanyId                        CompanyName  \
# 1       32608.658377        338                J. Strickland & Co.
# 2       32608.658377        338                J. Strickland & Co.
# 6         310.000000         11                  OPI PRODUCTS INC.
# 7         311.000000         11                  OPI PRODUCTS INC.
# 8         312.000000         11                  OPI PRODUCTS INC.
# ...              ...        ...                                ...
# 114568  32608.658377        886               Kendo Holdings, Inc.
# 114569  32608.658377        886               Kendo Holdings, Inc.
# 114570  64979.000000       1250  NINGBO MEITELI COSMETICS CO.,LTD.
# 114571  64980.000000       1250  NINGBO MEITELI COSMETICS CO.,LTD.
# 114572  64981.000000       1250  NINGBO MEITELI COSMETICS CO.,LTD.
#
#                                       BrandName  PrimaryCategoryId  \
# 1                                      Glover's                 18
# 2                                      Glover's                 18
# 6                                           OPI                 59
# 7                                           OPI                 59
# 8                                           OPI                 59
# ...                                         ...                ...
# 114568                       MARC JACOBS BEAUTY                 44
# 114569                       MARC JACOBS BEAUTY                 44
# 114570  NANJING CHANGJIANG PETROLEUM & CHEMICAL                 44
# 114571  NANJING CHANGJIANG PETROLEUM & CHEMICAL                 90
# 114572  NANJING CHANGJIANG PETROLEUM & CHEMICAL                 90
#
#                           PrimaryCategory  SubCategoryId  \
# 1       Hair Care Products (non-coloring)             25
# 2       Hair Care Products (non-coloring)             25
# 6                           Nail Products             60
# 7                           Nail Products             60
# 8                           Nail Products             60
# ...                                   ...            ...
# 114568    Makeup Products (non-permanent)             48
# 114569    Makeup Products (non-permanent)             46
# 114570    Makeup Products (non-permanent)             52
# 114571                Skin Care Products             102
# 114572                Skin Care Products             102
#
#                                         SubCategory  CasId  ChemicalId  \
# 1          Hair Shampoos (making a cosmetic claim)     889           4
# 2          Hair Shampoos (making a cosmetic claim)     293           5
# 6             Artificial Nails and Related Products    656       12178
# 7             Artificial Nails and Related Products    656       12178
# 8             Artificial Nails and Related Products    656       12178
# ...                                             ...    ...         ...
# 114568                                   Eye Shadow    759       68019
# 114569                     Eyeliner/Eyebrow Pencils    656       68020
# 114570                              Lip Gloss/Shine    759       68021
# 114571  Skin Moisturizers (making a cosmetic claim)    759       68022
# 114572  Skin Moisturizers (making a cosmetic claim)    759       68023
#
#                                       ChemicalName InitialDateReported  \
# 1                           Distillates (coal tar)          07/01/2009
# 2                                        Estragole          07/01/2009
# 6                                 Titanium dioxide          07/13/2009
# 7                                 Titanium dioxide          07/13/2009
# 8                                 Titanium dioxide          07/13/2009
# ...                                            ...                 ...
# 114568  Mineral oils, untreated and mildly treated          06/05/2020
# 114569                            Titanium dioxide          06/05/2020
# 114570  Mineral oils, untreated and mildly treated          06/07/2020
# 114571  Mineral oils, untreated and mildly treated          06/07/2020
# 114572  Mineral oils, untreated and mildly treated          06/07/2020
#
#        MostRecentDateReported ChemicalCreatedAt ChemicalUpdatedAt  \
# 1                  2009-07-01        2009-07-01        2009-07-01
# 2                  2009-07-01        2009-07-02        2009-07-02
# 6                  2010-12-30        2009-12-04        2009-12-04
# 7                  2010-12-30        2009-12-04        2009-12-04
# 8                  2010-12-30        2009-12-04        2009-12-04
# ...                       ...               ...               ...
# 114568             2020-06-05        2020-06-05        2020-06-05
# 114569             2020-06-05        2020-06-05        2020-06-05
# 114570             2020-06-07        2020-06-07        2020-06-07
# 114571             2020-06-07        2020-06-07        2020-06-07
# 114572             2020-06-07        2020-06-07        2020-06-07
#
#         ChemicalCount
# 1                   2
# 2                   2
# 6                   1
# 7                   1
# 8                   1
# ...               ...
# 114568              4
# 114569              1
# 114570              1
# 114571              1
# 114572              1
#
# [32423 rows x 18 columns]
